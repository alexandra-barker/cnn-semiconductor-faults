# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from google.colab import drive
import os
import matplotlib.pyplot as plt

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Define the shared folder path in Google Drive
shared_folder_path = '/content/drive/MyDrive/DATASCI 207 Project/data'

# Paths for each file
X_train_path = os.path.join(shared_folder_path, 'X_train.npy')
y_train_path = os.path.join(shared_folder_path, 'y_train.npy')
X_val_path = os.path.join(shared_folder_path, 'X_val.npy')
y_val_path = os.path.join(shared_folder_path, 'y_val.npy')
X_test_path = os.path.join(shared_folder_path, 'X_test.npy')
y_test_path = os.path.join(shared_folder_path, 'y_test.npy')

# Load the datasets
X_train = np.load(X_train_path)
y_train = np.load(y_train_path)
X_val = np.load(X_val_path)
y_val = np.load(y_val_path)
X_test = np.load(X_test_path)
y_test = np.load(y_test_path)

# Confirm the data has been loaded
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Mounted at /content/drive
# X_train shape: (30000, 50, 50, 1)
# y_train shape: (30000,)
# X_val shape: (34037, 50, 50, 1)
# y_val shape: (34037,)
# X_test shape: (34038, 50, 50, 1)
# y_test shape: (34038,)

# %%
final_class_distribution = dict(zip(*np.unique(y_val, return_counts=True)))
print("Final class distribution:", final_class_distribution)
# Out:
# Final class distribution: {0: 29538, 1: 831, 2: 1001, 3: 1951, 4: 716}

# %%
def plot_images(images, labels, nrows=2, ncols=5, cmap='gray'):
    plt.figure(figsize=(10, 5))
    for i in range(nrows * ncols):
        plt.subplot(nrows, ncols, i + 1)
        plt.imshow(images[i], cmap=cmap)
        plt.title(f"Label: {labels[i]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
# Visualize first 10 images from the training set
plot_images(X_train, y_train, nrows=2, ncols=5)

# Visualize first 10 images from the validation set
plot_images(X_val, y_val, nrows=2, ncols=5)

# Visualize first 10 images from the test set
plot_images(X_test[29955:], y_test[29955:], nrows=2, ncols=5)

# %%
def get_model(img_size, num_classes, kernel_size):
    np.random.seed(1234)
    tf.random.set_seed(1234)

    inputs = keras.Input(shape=img_size + (1,))

    x = layers.Conv2D(32, kernel_size=(kernel_size, kernel_size), activation='relu')(inputs)
    x = layers.MaxPooling2D(pool_size=(2, 2))(x)

    x = layers.Conv2D(64, kernel_size=(kernel_size, kernel_size), activation='relu')(x)
    x = layers.MaxPooling2D(pool_size=(2, 2))(x)

    x = layers.Conv2D(128, kernel_size=(kernel_size, kernel_size), activation='relu')(x)
    # x = layers.MaxPooling2D(pool_size=(2, 2))(x)


    x = layers.Flatten()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = keras.Model(inputs, outputs)
    return model

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

np.random.seed(1234)
tf.random.set_seed(1234)
# Define image size and number of classes
img_size = (50, 50)
num_classes = 5
kernel_size = 5

# Get the model
model = get_model(img_size=img_size, num_classes=num_classes, kernel_size = kernel_size)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=100,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.3517 - loss: 1.3929 - val_accuracy: 0.7007 - val_loss: 1.0683
# Epoch 2/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5349 - loss: 1.0875 - val_accuracy: 0.8467 - val_loss: 0.6840
# Epoch 3/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.6514 - loss: 0.8431 - val_accuracy: 0.8509 - val_loss: 0.6198
# Epoch 4/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6954 - loss: 0.7364 - val_accuracy: 0.8739 - val_loss: 0.5670
# Epoch 5/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7231 - loss: 0.6787 - val_accuracy: 0.8658 - val_loss: 0.5372
# Epoch 6/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.7412 - loss: 0.6396 - val_accuracy: 0.9233 - val_loss: 0.3763
# Epoch 7/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7505 - loss: 0.6074 - val_accuracy: 0.9209 - val_loss: 0.3613
# Epoch 8/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7607 - loss: 0.5859 - val_accuracy: 0.9232 - val_loss: 0.3726
# Epoch 9/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7722 - loss: 0.5685 - val_accuracy: 0.9242 - val_loss: 0.3475
# Epoch 10/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7803 - loss: 0.5468 - val_accuracy: 0.9306 - val_loss: 0.3125
# Epoch 11/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7837 - loss: 0.5364 - val_accuracy: 0.9318 - val_loss: 0.3353
# Epoch 12/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7912 - loss: 0.5179 - val_accuracy: 0.9229 - val_loss: 0.3405
# Epoch 13/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7967 - loss: 0.5089 - val_accuracy: 0.9324 - val_loss: 0.2981
# Epoch 14/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8066 - loss: 0.4896 - val_accuracy: 0.9169 - val_loss: 0.3437
# Epoch 15/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8102 - loss: 0.4781 - val_accuracy: 0.9368 - val_loss: 0.2695
# Epoch 16/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8148 - loss: 0.4730 - val_accuracy: 0.9400 - val_loss: 0.2629
# Epoch 17/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8161 - loss: 0.4594 - val_accuracy: 0.9347 - val_loss: 0.2803
# Epoch 18/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8228 - loss: 0.4477 - val_accuracy: 0.9408 - val_loss: 0.2460
# Epoch 19/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8208 - loss: 0.4485 - val_accuracy: 0.9175 - val_loss: 0.3311
# Epoch 20/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8306 - loss: 0.4304 - val_accuracy: 0.9209 - val_loss: 0.3146
# Epoch 21/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8328 - loss: 0.4249 - val_accuracy: 0.9355 - val_loss: 0.2784
# Epoch 22/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8352 - loss: 0.4128 - val_accuracy: 0.9336 - val_loss: 0.2688
# Epoch 23/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8396 - loss: 0.4080 - val_accuracy: 0.9196 - val_loss: 0.3187
# Epoch 24/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8458 - loss: 0.3934 - val_accuracy: 0.9309 - val_loss: 0.2891
# Epoch 25/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8457 - loss: 0.3921 - val_accuracy: 0.9299 - val_loss: 0.2873
# Epoch 26/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8509 - loss: 0.3818 - val_accuracy: 0.9358 - val_loss: 0.2558
# Epoch 27/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8522 - loss: 0.3768 - val_accuracy: 0.9367 - val_loss: 0.2601
# Epoch 28/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8499 - loss: 0.3722 - val_accuracy: 0.9385 - val_loss: 0.2499

# %%
train_loss, train_acc = model.evaluate(X_train, y_train, verbose = 2)
val_loss, val_acc = model.evaluate(X_val, y_val, verbose = 2)

print(f"Train accuracy: {train_acc: .3f}")
print(f"Val accuracy: {val_acc: .3f}")
# Out:
# 938/938 - 3s - 3ms/step - accuracy: 0.8384 - loss: 0.4048
# 1064/1064 - 3s - 2ms/step - accuracy: 0.9408 - loss: 0.2460
# Train accuracy:  0.838
# Val accuracy:  0.941

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose = 2)
# Out:
# 1064/1064 - 3s - 3ms/step - accuracy: 0.9397 - loss: 0.2479

# %%
test_acc
# Out:
# 0.9397438168525696

# %%
# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

plt.tight_layout()
plt.show()

# %%
# Encode 'failureType' labels as integers for modeling
label_mapping = {
    'none': 0,
    'Center': 1,
    'Edge-Loc': 2,
    'Edge-Ring': 3,
    'Loc': 4

}

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Predict on test set
y_test_pred = model.predict(X_test)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_test_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_mapping.keys(), yticklabels=label_mapping.keys())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
report = classification_report(y_test, y_test_pred_classes, target_names=label_mapping.keys())
print(report)
# Out:
# 1064/1064 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
#               precision    recall  f1-score   support
#
#         none       0.99      0.95      0.97     29476
#       Center       0.64      0.95      0.77       879
#     Edge-Loc       0.51      0.71      0.59      1042
#    Edge-Ring       0.87      0.94      0.91      1940
#          Loc       0.65      0.73      0.69       701
#
#     accuracy                           0.94     34038
#    macro avg       0.73      0.86      0.79     34038
# weighted avg       0.95      0.94      0.94     34038

# %%
# Print the class distribution in the training set
unique, frequency = np.unique(y_test, return_counts=True)
class_distribution = dict(zip(unique, frequency))
print("Class Distribution:", class_distribution)
# Out:
# Class Distribution: {0: 29476, 1: 879, 2: 1042, 3: 1940, 4: 701}

# %%
# Encode 'failureType' labels as integers for modeling
label_mapping = {
    'none': 0,
    'Center': 1,
    'Edge-Loc': 2,
    'Edge-Ring': 3,
    'Loc': 4

}
